# %% [markdown]
# # Exploratory Data Analysis

# %% [markdown]
# *** Importing Libraries ***

# %%
#Regular EDA(Exploratory Data Analysis) & Plotting Libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.compose import make_column_transformer
from sklearn.preprocessing import MinMaxScaler, OneHotEncoder
from sklearn.model_selection import train_test_split

# %matplotlib inline

# %%
Stroke = pd.read_csv("https://raw.githubusercontent.com/kuchbhi-kunal/nidan/main/healthcare-dataset-stroke-data.csv")

# %%
Stroke
# Out:
#          id  gender   age  hypertension  heart_disease ever_married  \
# 0      9046    Male  67.0             0              1          Yes
# 1     51676  Female  61.0             0              0          Yes
# 2     31112    Male  80.0             0              1          Yes
# 3     60182  Female  49.0             0              0          Yes
# 4      1665  Female  79.0             1              0          Yes
# ...     ...     ...   ...           ...            ...          ...
# 5105  18234  Female  80.0             1              0          Yes
# 5106  44873  Female  81.0             0              0          Yes
# 5107  19723  Female  35.0             0              0          Yes
# 5108  37544    Male  51.0             0              0          Yes
# 5109  44679  Female  44.0             0              0          Yes
#
#           work_type Residence_type  avg_glucose_level   bmi   smoking_status  \
# 0           Private          Urban             228.69  36.6  formerly smoked
# 1     Self-employed          Rural             202.21   NaN     never smoked
# 2           Private          Rural             105.92  32.5     never smoked
# 3           Private          Urban             171.23  34.4           smokes
# 4     Self-employed          Rural             174.12  24.0     never smoked
# ...             ...            ...                ...   ...              ...
# 5105        Private          Urban              83.75   NaN     never smoked
# 5106  Self-employed          Urban             125.20  40.0     never smoked
# 5107  Self-employed          Rural              82.99  30.6     never smoked
# 5108        Private          Rural             166.29  25.6  formerly smoked
# 5109       Govt_job          Urban              85.28  26.2          Unknown
#
#       stroke
# 0          1
# 1          1
# 2          1
# 3          1
# 4          1
# ...      ...
# 5105       0
# 5106       0
# 5107       0
# 5108       0
# 5109       0
#
# [5110 rows x 12 columns]

# %%
Stroke.drop("id",axis=1,inplace = True)

# %%
Stroke['hypertension'].value_counts()
# Out:
# 0    4612
# 1     498
# Name: hypertension, dtype: int64

# %%
Stroke.hist(figsize=(50,50), bins=50, color="red");

# %%
Stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5110 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5110 non-null   object
#  1   age                5110 non-null   float64
#  2   hypertension       5110 non-null   int64
#  3   heart_disease      5110 non-null   int64
#  4   ever_married       5110 non-null   object
#  5   work_type          5110 non-null   object
#  6   Residence_type     5110 non-null   object
#  7   avg_glucose_level  5110 non-null   float64
#  8   bmi                4909 non-null   float64
#  9   smoking_status     5110 non-null   object
#  10  stroke             5110 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 439.3+ KB

# %%
Stroke.isna().sum()
# Out:
# gender                 0
# age                    0
# hypertension           0
# heart_disease          0
# ever_married           0
# work_type              0
# Residence_type         0
# avg_glucose_level      0
# bmi                  201
# smoking_status         0
# stroke                 0
# dtype: int64

# %%
Stroke['gender'].value_counts()
# Out:
# Female    2994
# Male      2115
# Other        1
# Name: gender, dtype: int64

# %%
print (Stroke[Stroke['gender'] == 'Other'].index.tolist())
# Out:
# [3116]

# %%
Stroke.drop([3116],inplace = True)

# %%
Stroke['ever_married'].value_counts().plot(kind='bar',color='red')
# Out:
# <Axes: >

# %%
Stroke['work_type'].value_counts().plot(kind='bar',color='black')
# Out:
# <Axes: >

# %%
Stroke['Residence_type'].value_counts().plot(kind='bar',color='green')
# Out:
# <Axes: >

# %%
Stroke['smoking_status'].value_counts().plot(kind='bar',color='Yellow')
# Out:
# <Axes: >

# %%
for label, content in Stroke.items():
    if pd.api.types.is_numeric_dtype(content):
        if pd.isnull(content).sum():
            #Fill missing numeric valuees with median
            Stroke[label] = content.fillna(content.median())

# %%
Stroke.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5109 entries, 0 to 5109
# Data columns (total 11 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   gender             5109 non-null   object
#  1   age                5109 non-null   float64
#  2   hypertension       5109 non-null   int64
#  3   heart_disease      5109 non-null   int64
#  4   ever_married       5109 non-null   object
#  5   work_type          5109 non-null   object
#  6   Residence_type     5109 non-null   object
#  7   avg_glucose_level  5109 non-null   float64
#  8   bmi                5109 non-null   float64
#  9   smoking_status     5109 non-null   object
#  10  stroke             5109 non-null   int64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 479.0+ KB

# %%
Stroke['work_type'].value_counts()
# Out:
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64

# %%
corr_matrix = Stroke.corr()
fig , ax = plt.subplots(figsize=(10,8))
ax = sns.heatmap(corr_matrix,
                annot=True,
                linewidths=0.5,
                fmt='.2f')

# %%
Stroke.drop('stroke', axis=1).corrwith(Stroke.stroke).plot(kind='bar', grid=True, figsize=(20, 8), title="Correlation with stroke Prediction",color="Black")
# Out:
# <Axes: title={'center': 'Correlation with stroke Prediction'}>

# %% [markdown]
# # Train Test Split

# %%
X= Stroke.drop('stroke',axis=1)
Y=Stroke['stroke']

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,random_state=42,stratify=Y)

# %%
X_train.hist(figsize=(50,50), bins=50, color="red");

# %%
Y_train.hist(figsize=(50,50), bins=50, color="red")
# Out:
# <Axes: >

# %%
Numeric = []
for label, content in Stroke.items():
    if pd.api.types.is_numeric_dtype(content):
      Numeric.append(label)

# %%
Numeric.remove('stroke')

# %%
Numeric
# Out:
# ['age', 'hypertension', 'heart_disease', 'avg_glucose_level', 'bmi']

# %%
Object = []
for label, content in Stroke.items():
    if not(pd.api.types.is_numeric_dtype(content)):
      Object.append(label)

# %%
Stroke.columns
# Out:
# Index(['gender', 'age', 'hypertension', 'heart_disease', 'ever_married',
#        'work_type', 'Residence_type', 'avg_glucose_level', 'bmi',
#        'smoking_status', 'stroke'],
#       dtype='object')

# %%
for i in range(0,len(Object)):
  print(Object[i],":-")
  print(Stroke[f"{Object[i]}"].value_counts())
  print('\n')
# Out:
# gender :-
# Female    2994
# Male      2115
# Name: gender, dtype: int64
#
#
# ever_married :-
# Yes    3353
# No     1756
# Name: ever_married, dtype: int64
#
#
# work_type :-
# Private          2924
# Self-employed     819
# children          687
# Govt_job          657
# Never_worked       22
# Name: work_type, dtype: int64
#
#
# Residence_type :-
# Urban    2596
# Rural    2513
# Name: Residence_type, dtype: int64
#
#
# smoking_status :-
# never smoked       1892
# Unknown            1544
# formerly smoked     884
# smokes              789
# Name: smoking_status, dtype: int64

# %%
Object
# Out:
# ['gender', 'ever_married', 'work_type', 'Residence_type', 'smoking_status']

# %%
Numeric.remove('hypertension')

# %%
Numeric.remove('heart_disease')

# %%
Object.append('hypertension')

# %%
Object.append('heart_disease')

# %%
ct = make_column_transformer(
    (MinMaxScaler(), Numeric),
    (OneHotEncoder(handle_unknown='ignore'),Object))

# %%
ct.fit(X_train)
# Out:
# ColumnTransformer(transformers=[('minmaxscaler', MinMaxScaler(),
#                                  ['age', 'avg_glucose_level', 'bmi']),
#                                 ('onehotencoder',
#                                  OneHotEncoder(handle_unknown='ignore'),
#                                  ['gender', 'ever_married', 'work_type',
#                                   'Residence_type', 'smoking_status',
#                                   'hypertension', 'heart_disease'])])

# %%
X_train_ct = ct.transform(X_train)

# %%
X_test_ct = ct.transform(X_test)

# %%
X_train_ct.shape
# Out:
# (4087, 22)

# %%
X_test_ct.shape
# Out:
# (1022, 22)

# %%
import xgboost as xgb
from sklearn.model_selection import GridSearchCV


param_grid = {
    "max_depth": [3, 4, 5, 7],
    "learning_rate": [0.1, 0.01, 0.05],
    "gamma": [0, 0.25, 1],
    "reg_lambda": [0, 1, 10],
    'booster': ['gbtree', 'gblinear'],
    "scale_pos_weight": [1, 3, 5],
    "subsample": [0.8],
    "colsample_bytree": [0.5],
}

# Init classifier
xgb_cl = xgb.XGBClassifier(subsample= 0.8,
 scale_pos_weight= 5,
 reg_lambda= 1,
 max_depth= 5,
 learning_rate= 0.01,
 gamma= 1,
 colsample_bytree= 0.5)

# Init Grid Search
grid_cv = GridSearchCV(xgb_cl, param_grid, n_jobs=-1, cv=3, scoring="accuracy",verbose=2)

# Fit
grid_cv.fit(X_train_ct, Y_train)
# Out:
# Fitting 3 folds for each of 648 candidates, totalling 1944 fits
# GridSearchCV(cv=3,
#              estimator=XGBClassifier(base_score=None, booster=None,
#                                      callbacks=None, colsample_bylevel=None,
#                                      colsample_bynode=None,
#                                      colsample_bytree=0.5,
#                                      early_stopping_rounds=None,
#                                      enable_categorical=False, eval_metric=None,
#                                      feature_types=None, gamma=1, gpu_id=None,
#                                      grow_policy=None, importance_type=None,
#                                      interaction_constraints=None,
#                                      learning_rate=0.01, max_...
#                                      missing=nan, monotone_constraints=None,
#                                      n_estimators=100, n_jobs=None,
#                                      num_parallel_tree=None, predictor=None,
#                                      random_state=None, ...),
#              n_jobs=-1,
#              param_grid={'booster': ['gbtree', 'gblinear'],
#                          'colsample_bytree': [0.5], 'gamma': [0, 0.25, 1],
#                          'learning_rate': [0.1, 0.01, 0.05],
#                          'max_depth': [3, 4, 5, 7], 'reg_lambda': [0, 1, 10],
#                          'scale_pos_weight': [1, 3, 5], 'subsample': [0.8]},
#              scoring='accuracy', verbose=2)

# %%
grid_cv.best_params_
# Out:
# {'booster': 'gbtree',
#  'colsample_bytree': 0.5,
#  'gamma': 0,
#  'learning_rate': 0.01,
#  'max_depth': 3,
#  'reg_lambda': 0,
#  'scale_pos_weight': 1,
#  'subsample': 0.8}

# %%
xgb_cl0 = xgb.XGBClassifier(subsample= 0.8,
 scale_pos_weight= 1,
 reg_lambda= 0,
 booster = 'gbtree',
 max_depth= 3,
 learning_rate= 0.01,
 gamma= 0,
 colsample_bytree= 0.5)

# %%
xgb_cl0.fit(X_train_ct,Y_train)
# Out:
# XGBClassifier(base_score=None, booster='gbtree', callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=0.5, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric=None, feature_types=None,
#               gamma=0, gpu_id=None, grow_policy=None, importance_type=None,
#               interaction_constraints=None, learning_rate=0.01, max_bin=None,
#               max_cat_threshold=None, max_cat_to_onehot=None,
#               max_delta_step=None, max_depth=3, max_leaves=None,
#               min_child_weight=None, missing=nan, monotone_constraints=None,
#               n_estimators=100, n_jobs=None, num_parallel_tree=None,
#               predictor=None, random_state=None, ...)

# %%
Y_pred=xgb_cl0.predict(X_test_ct)

# %%
from sklearn.metrics import accuracy_score
accuracy_score(Y_pred,Y_test)
# Out:
# 0.9510763209393346

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=Y_test, y_pred=Y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       972
#            1       0.00      0.00      0.00        50
#
#     accuracy                           0.95      1022
#    macro avg       0.48      0.50      0.49      1022
# weighted avg       0.90      0.95      0.93      1022
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from sklearn.metrics import confusion_matrix
sns.set(font_scale=1.5)
def plot_confusion(y_test,y_preds):
    #Creating Heatmap of Confusion matrix"
    fig, ax = plt.subplots(figsize=(3,3))
    ax = sns.heatmap(confusion_matrix(y_test,y_preds),
                    annot=True,
                    cbar=False)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

# %%
# %%time
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV

#Different HyperParameters
rf_grid = {"n_estimators": np.arange(10,100,10),
          "max_depth": [None,3,5,10],
          "min_samples_split":np.arange(2,10,2),
          "min_samples_leaf":np.arange(1,10,2),
          "max_features":[0.5,1,"sqrt",'log2']}

#Instatantiate Randomised Search CV
rs_model = RandomizedSearchCV(RandomForestClassifier(n_jobs=-1,random_state=42),
                             param_distributions=rf_grid,
                             cv=5,
                             verbose=2,
                             n_iter=1000,
                        return_train_score=True)
rs_model.fit(X_train_ct,Y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=7, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=7, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=7, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=7, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=7, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=30; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=80; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=40; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=40; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=6, n_estimators=80; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=6, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=70; total time=   0.3s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.4s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=90; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=90; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=90; total time=   0.4s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=90; total time=   0.3s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=90; total time=   0.3s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=60; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=1, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=9, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=80; total time=   0.5s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=80; total time=   0.5s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=80; total time=   0.5s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=9, min_samples_split=4, n_estimators=80; total time=   0.5s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=10; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=5, min_samples_split=6, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=2, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=4, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.4s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=30; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=3, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=7, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=7, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=7, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=7, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=7, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=9, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=90; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=90; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=90; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=90; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=8, n_estimators=90; total time=   0.4s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=5, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=70; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=2, n_estimators=50; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.5s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.4s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=60; total time=   0.3s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=5, min_samples_split=2, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=5, min_samples_split=6, n_estimators=10; total time=   0.0s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=9, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=5, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=60; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=90; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.2s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=7, min_samples_split=4, n_estimators=20; total time=   0.2s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.3s
# [CV] END max_depth=5, max_features=0.5, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.3s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=10, max_features=0.5, min_samples_leaf=5, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=70; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=20; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=1, min_samples_split=2, n_estimators=50; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=3, min_samples_split=4, n_estimators=40; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=6, n_estimators=90; total time=   0.3s
# ...
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=5, min_samples_split=2, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=7, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=70; total time=   0.4s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=3, min_samples_split=2, n_estimators=70; total time=   0.4s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=6, n_estimators=30; total time=   0.1s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.3s
# [CV] END max_depth=3, max_features=log2, min_samples_leaf=3, min_samples_split=8, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=10; total time=   0.0s
# [CV] END max_depth=3, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=10; total time=   0.1s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=7, min_samples_split=8, n_estimators=70; total time=   0.2s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=sqrt, min_samples_leaf=5, min_samples_split=8, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=log2, min_samples_leaf=9, min_samples_split=2, n_estimators=80; total time=   0.3s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.1s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=10, max_features=log2, min_samples_leaf=5, min_samples_split=4, n_estimators=30; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=6, n_estimators=70; total time=   0.5s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=6, n_estimators=70; total time=   0.5s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=6, n_estimators=70; total time=   0.5s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=6, n_estimators=70; total time=   0.5s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=6, n_estimators=70; total time=   0.5s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=sqrt, min_samples_leaf=1, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.4s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=9, min_samples_split=8, n_estimators=80; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=90; total time=   0.2s
# [CV] END max_depth=3, max_features=1, min_samples_leaf=9, min_samples_split=6, n_estimators=90; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.2s
# [CV] END max_depth=5, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=60; total time=   0.1s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.3s
# [CV] END max_depth=None, max_features=1, min_samples_leaf=1, min_samples_split=4, n_estimators=80; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=60; total time=   0.3s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=60; total time=   0.2s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=5, min_samples_split=4, n_estimators=60; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.2s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.1s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.3s
# [CV] END max_depth=5, max_features=sqrt, min_samples_leaf=3, min_samples_split=8, n_estimators=50; total time=   0.3s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.2s
# [CV] END max_depth=10, max_features=1, min_samples_leaf=1, min_samples_split=8, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=5, max_features=log2, min_samples_leaf=7, min_samples_split=6, n_estimators=40; total time=   0.2s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=3, max_features=0.5, min_samples_leaf=1, min_samples_split=6, n_estimators=20; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=30; total time=   0.1s
# [CV] END max_depth=None, max_features=0.5, min_samples_leaf=7, min_samples_split=2, n_estimators=30; total time=   0.1s
# CPU times: user 8min 33s, sys: 1min 6s, total: 9min 40s
# Wall time: 17min 59s
# RandomizedSearchCV(cv=5,
#                    estimator=RandomForestClassifier(n_jobs=-1, random_state=42),
#                    n_iter=1000,
#                    param_distributions={'max_depth': [None, 3, 5, 10],
#                                         'max_features': [0.5, 1, 'sqrt',
#                                                          'log2'],
#                                         'min_samples_leaf': array([1, 3, 5, 7, 9]),
#                                         'min_samples_split': array([2, 4, 6, 8]),
#                                         'n_estimators': array([10, 20, 30, 40, 50, 60, 70, 80, 90])},
#                    return_train_score=True, verbose=2)

# %%
rs_model.best_params_
# Out:
# {'n_estimators': 80,
#  'min_samples_split': 2,
#  'min_samples_leaf': 1,
#  'max_features': 'sqrt',
#  'max_depth': 10}

# %%
RF1 = RandomForestClassifier(n_jobs=-1,random_state=42,n_estimators= 10,
 min_samples_split= 6,
 min_samples_leaf= 9,
 max_features= 0.5,
 max_depth =None)

# %%
RF1.fit(X_train_ct, Y_train)
# Out:
# RandomForestClassifier(max_features=0.5, min_samples_leaf=9,
#                        min_samples_split=6, n_estimators=10, n_jobs=-1,
#                        random_state=42)

# %%
Y_preds_RF=RF1.predict(X_test_ct)

# %%
plot_confusion(Y_test,Y_preds_RF)

# %%
from sklearn.model_selection import cross_val_predict

Y_scores = cross_val_predict(RF1, X_train_ct, Y_train, cv=3, method='predict_proba')

# %%
Y_scores_Forest = Y_scores[:,1]
len(Y_scores_Forest), len(Y_train)
# Out:
# (4087, 4087)

# %%
from sklearn.metrics import roc_curve
fpr_forest, tpr_forest, thresholds_forest = roc_curve(Y_train,Y_scores_Forest)

# %%
def plot_roc_curve(fpr, tpr, label=None):
  plt.plot(fpr,tpr,linewidth=2,label=label)
  plt.plot([0,1],[0,1],'k--')

plot_roc_curve(fpr_forest,tpr_forest)

# %%
print(classification_report(y_true=Y_test, y_pred=Y_preds_RF))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.95      1.00      0.97       972
#            1       0.00      0.00      0.00        50
#
#     accuracy                           0.95      1022
#    macro avg       0.48      0.50      0.49      1022
# weighted avg       0.90      0.95      0.93      1022
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
Y_train = tf.constant(Y_train)

# %%
import tensorflow as tf
# Set Random seed
tf.random.set_seed(42)

#1. Create the Model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(1,activation='sigmoid')
])

#2. Compile the Model
model_3.compile(loss=tf.keras.losses.BinaryCrossentropy(),
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#3. Fit the Model
history = model_3.fit(X_train_ct,Y_train,epochs=100)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 2s 4ms/step - loss: 0.2419 - accuracy: 0.9308
# Epoch 2/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1767 - accuracy: 0.9513
# Epoch 3/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1718 - accuracy: 0.9513
# Epoch 4/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1684 - accuracy: 0.9513
# Epoch 5/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1660 - accuracy: 0.9513
# Epoch 6/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1620 - accuracy: 0.9513
# Epoch 7/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1598 - accuracy: 0.9513
# Epoch 8/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1573 - accuracy: 0.9513
# Epoch 9/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1551 - accuracy: 0.9513
# Epoch 10/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1541 - accuracy: 0.9511
# Epoch 11/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1525 - accuracy: 0.9518
# Epoch 12/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1562 - accuracy: 0.9518
# Epoch 13/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1517 - accuracy: 0.9516
# Epoch 14/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1537 - accuracy: 0.9518
# Epoch 15/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1514 - accuracy: 0.9516
# Epoch 16/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1534 - accuracy: 0.9516
# Epoch 17/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1509 - accuracy: 0.9518
# Epoch 18/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1505 - accuracy: 0.9513
# Epoch 19/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1502 - accuracy: 0.9516
# Epoch 20/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1452 - accuracy: 0.9516
# Epoch 21/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 0.9513
# Epoch 22/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1460 - accuracy: 0.9518
# Epoch 23/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1470 - accuracy: 0.9520
# Epoch 24/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1459 - accuracy: 0.9523
# Epoch 25/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1472 - accuracy: 0.9525
# Epoch 26/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1448 - accuracy: 0.9525
# Epoch 27/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1444 - accuracy: 0.9533
# Epoch 28/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1433 - accuracy: 0.9540
# Epoch 29/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1427 - accuracy: 0.9533
# Epoch 30/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1423 - accuracy: 0.9542
# Epoch 31/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1409 - accuracy: 0.9545
# Epoch 32/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1435 - accuracy: 0.9540
# Epoch 33/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1400 - accuracy: 0.9547
# Epoch 34/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1398 - accuracy: 0.9545
# Epoch 35/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1387 - accuracy: 0.9552
# Epoch 36/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1374 - accuracy: 0.9547
# Epoch 37/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1370 - accuracy: 0.9550
# Epoch 38/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1367 - accuracy: 0.9550
# Epoch 39/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1358 - accuracy: 0.9555
# Epoch 40/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9547
# Epoch 41/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1347 - accuracy: 0.9542
# Epoch 42/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1344 - accuracy: 0.9552
# Epoch 43/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1338 - accuracy: 0.9564
# Epoch 44/100
# 128/128 [==============================] - 1s 7ms/step - loss: 0.1332 - accuracy: 0.9552
# Epoch 45/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1336 - accuracy: 0.9555
# Epoch 46/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1321 - accuracy: 0.9562
# Epoch 47/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.9562
# Epoch 48/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1325 - accuracy: 0.9550
# Epoch 49/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1313 - accuracy: 0.9567
# Epoch 50/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9550
# Epoch 51/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1302 - accuracy: 0.9564
# Epoch 52/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1315 - accuracy: 0.9557
# Epoch 53/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9555
# Epoch 54/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1278 - accuracy: 0.9572
# Epoch 55/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1300 - accuracy: 0.9569
# Epoch 56/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1274 - accuracy: 0.9564
# Epoch 57/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1270 - accuracy: 0.9555
# Epoch 58/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1271 - accuracy: 0.9557
# Epoch 59/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1275 - accuracy: 0.9577
# Epoch 60/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1285 - accuracy: 0.9550
# Epoch 61/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1262 - accuracy: 0.9567
# Epoch 62/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1255 - accuracy: 0.9550
# Epoch 63/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1249 - accuracy: 0.9572
# Epoch 64/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1263 - accuracy: 0.9572
# Epoch 65/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1245 - accuracy: 0.9562
# Epoch 66/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1216 - accuracy: 0.9569
# Epoch 67/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1231 - accuracy: 0.9569
# Epoch 68/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1242 - accuracy: 0.9567
# Epoch 69/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1240 - accuracy: 0.9562
# Epoch 70/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1219 - accuracy: 0.9572
# Epoch 71/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1214 - accuracy: 0.9567
# Epoch 72/100
# 128/128 [==============================] - 1s 7ms/step - loss: 0.1204 - accuracy: 0.9579
# Epoch 73/100
# 128/128 [==============================] - 1s 8ms/step - loss: 0.1209 - accuracy: 0.9572
# Epoch 74/100
# 128/128 [==============================] - 1s 7ms/step - loss: 0.1203 - accuracy: 0.9562
# Epoch 75/100
# 128/128 [==============================] - 1s 7ms/step - loss: 0.1199 - accuracy: 0.9579
# Epoch 76/100
# 128/128 [==============================] - 1s 8ms/step - loss: 0.1193 - accuracy: 0.9582
# Epoch 77/100
# 128/128 [==============================] - 1s 7ms/step - loss: 0.1192 - accuracy: 0.9572
# Epoch 78/100
# 128/128 [==============================] - 1s 8ms/step - loss: 0.1215 - accuracy: 0.9572
# Epoch 79/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1194 - accuracy: 0.9577
# Epoch 80/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1181 - accuracy: 0.9582
# Epoch 81/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1182 - accuracy: 0.9562
# Epoch 82/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1185 - accuracy: 0.9572
# Epoch 83/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1164 - accuracy: 0.9589
# Epoch 84/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1165 - accuracy: 0.9579
# Epoch 85/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1163 - accuracy: 0.9574
# Epoch 86/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1150 - accuracy: 0.9594
# Epoch 87/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1164 - accuracy: 0.9586
# Epoch 88/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1159 - accuracy: 0.9584
# Epoch 89/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1150 - accuracy: 0.9589
# Epoch 90/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1139 - accuracy: 0.9596
# Epoch 91/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1145 - accuracy: 0.9574
# Epoch 92/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1140 - accuracy: 0.9601
# Epoch 93/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1128 - accuracy: 0.9586
# Epoch 94/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1122 - accuracy: 0.9589
# Epoch 95/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1125 - accuracy: 0.9596
# Epoch 96/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9606
# Epoch 97/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1117 - accuracy: 0.9611
# Epoch 98/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 0.9586
# Epoch 99/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1121 - accuracy: 0.9611
# Epoch 100/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1116 - accuracy: 0.9594

# %%
tf_pred = model_3.predict(X_test_ct)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
tf_pred
# Out:
# array([[1.3164857e-03],
#        [3.2534283e-03],
#        [9.1323644e-02],
#        ...,
#        [4.1608843e-03],
#        [4.3668610e-08],
#        [1.6916356e-03]], dtype=float32)

# %%
Y_preds_round=tf.round(tf_pred)

# %%
Y_preds_round
# Out:
# <tf.Tensor: shape=(1022, 1), dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        ...,
#        [0.],
#        [0.],
#        [0.]], dtype=float32)>

# %%
from sklearn.metrics import confusion_matrix
sns.set(font_scale=1.5)
def plot_confusion(y_test,y_preds):
    #Creating Heatmap of Confusion matrix"
    fig, ax = plt.subplots(figsize=(3,3))
    ax = sns.heatmap(confusion_matrix(y_test,y_preds),
                    annot=True,
                    cbar=False)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")

# %%
plot_confusion(Y_test,Y_preds_round)

# %%
import tensorflow as tf
# Set Random seed
tf.random.set_seed(42)

#1. Create the Model
model_4 = tf.keras.Sequential([
    tf.keras.layers.Dense(10),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(100,activation='relu'),
    tf.keras.layers.Dense(2,activation='softmax')
])

#2. Compile the Model
model_4.compile(loss='sparse_categorical_crossentropy',
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['accuracy'])

#3. Fit the Model
history1 = model_4.fit(X_train_ct,Y_train,epochs=100)
# Out:
# Epoch 1/100
# 128/128 [==============================] - 2s 4ms/step - loss: 0.2179 - accuracy: 0.9467
# Epoch 2/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1761 - accuracy: 0.9513
# Epoch 3/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1693 - accuracy: 0.9513
# Epoch 4/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1637 - accuracy: 0.9513
# Epoch 5/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1608 - accuracy: 0.9513
# Epoch 6/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1581 - accuracy: 0.9513
# Epoch 7/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1563 - accuracy: 0.9513
# Epoch 8/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1542 - accuracy: 0.9513
# Epoch 9/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1532 - accuracy: 0.9513
# Epoch 10/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1524 - accuracy: 0.9513
# Epoch 11/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1508 - accuracy: 0.9513
# Epoch 12/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1548 - accuracy: 0.9513
# Epoch 13/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9513
# Epoch 14/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1523 - accuracy: 0.9513
# Epoch 15/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1485 - accuracy: 0.9520
# Epoch 16/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1512 - accuracy: 0.9525
# Epoch 17/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1485 - accuracy: 0.9513
# Epoch 18/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1474 - accuracy: 0.9525
# Epoch 19/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1491 - accuracy: 0.9525
# Epoch 20/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1425 - accuracy: 0.9542
# Epoch 21/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1478 - accuracy: 0.9535
# Epoch 22/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.1412 - accuracy: 0.9542
# Epoch 23/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1430 - accuracy: 0.9538
# Epoch 24/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1401 - accuracy: 0.9555
# Epoch 25/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1423 - accuracy: 0.9545
# Epoch 26/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1389 - accuracy: 0.9555
# Epoch 27/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1386 - accuracy: 0.9545
# Epoch 28/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1361 - accuracy: 0.9550
# Epoch 29/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1361 - accuracy: 0.9555
# Epoch 30/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1345 - accuracy: 0.9562
# Epoch 31/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1339 - accuracy: 0.9560
# Epoch 32/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1366 - accuracy: 0.9552
# Epoch 33/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1317 - accuracy: 0.9564
# Epoch 34/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1318 - accuracy: 0.9562
# Epoch 35/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1309 - accuracy: 0.9552
# Epoch 36/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1294 - accuracy: 0.9569
# Epoch 37/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9569
# Epoch 38/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1258 - accuracy: 0.9572
# Epoch 39/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1263 - accuracy: 0.9574
# Epoch 40/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1244 - accuracy: 0.9569
# Epoch 41/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1280 - accuracy: 0.9569
# Epoch 42/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1243 - accuracy: 0.9582
# Epoch 43/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1222 - accuracy: 0.9572
# Epoch 44/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1203 - accuracy: 0.9589
# Epoch 45/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.1236 - accuracy: 0.9572
# Epoch 46/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1212 - accuracy: 0.9577
# Epoch 47/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1207 - accuracy: 0.9577
# Epoch 48/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1194 - accuracy: 0.9572
# Epoch 49/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1171 - accuracy: 0.9579
# Epoch 50/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1169 - accuracy: 0.9579
# Epoch 51/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1173 - accuracy: 0.9589
# Epoch 52/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1152 - accuracy: 0.9604
# Epoch 53/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1158 - accuracy: 0.9586
# Epoch 54/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1146 - accuracy: 0.9589
# Epoch 55/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1148 - accuracy: 0.9604
# Epoch 56/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1134 - accuracy: 0.9594
# Epoch 57/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.1113 - accuracy: 0.9591
# Epoch 58/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1109 - accuracy: 0.9606
# Epoch 59/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1104 - accuracy: 0.9596
# Epoch 60/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1114 - accuracy: 0.9591
# Epoch 61/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1111 - accuracy: 0.9604
# Epoch 62/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1083 - accuracy: 0.9616
# Epoch 63/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1090 - accuracy: 0.9616
# Epoch 64/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1076 - accuracy: 0.9616
# Epoch 65/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1050 - accuracy: 0.9609
# Epoch 66/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1020 - accuracy: 0.9613
# Epoch 67/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1037 - accuracy: 0.9623
# Epoch 68/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1025 - accuracy: 0.9618
# Epoch 69/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1048 - accuracy: 0.9613
# Epoch 70/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1035 - accuracy: 0.9623
# Epoch 71/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1045 - accuracy: 0.9628
# Epoch 72/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.1003 - accuracy: 0.9638
# Epoch 73/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.0990 - accuracy: 0.9640
# Epoch 74/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1000 - accuracy: 0.9633
# Epoch 75/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1005 - accuracy: 0.9628
# Epoch 76/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0993 - accuracy: 0.9628
# Epoch 77/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0963 - accuracy: 0.9653
# Epoch 78/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1002 - accuracy: 0.9631
# Epoch 79/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.0983 - accuracy: 0.9628
# Epoch 80/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.1002 - accuracy: 0.9631
# Epoch 81/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0957 - accuracy: 0.9609
# Epoch 82/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.0973 - accuracy: 0.9635
# Epoch 83/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0978 - accuracy: 0.9635
# Epoch 84/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0924 - accuracy: 0.9665
# Epoch 85/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0927 - accuracy: 0.9643
# Epoch 86/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0892 - accuracy: 0.9687
# Epoch 87/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.0939 - accuracy: 0.9633
# Epoch 88/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0914 - accuracy: 0.9653
# Epoch 89/100
# 128/128 [==============================] - 0s 3ms/step - loss: 0.0910 - accuracy: 0.9653
# Epoch 90/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0903 - accuracy: 0.9667
# Epoch 91/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0908 - accuracy: 0.9660
# Epoch 92/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0882 - accuracy: 0.9660
# Epoch 93/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0899 - accuracy: 0.9643
# Epoch 94/100
# 128/128 [==============================] - 1s 4ms/step - loss: 0.0883 - accuracy: 0.9667
# Epoch 95/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0882 - accuracy: 0.9679
# Epoch 96/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0850 - accuracy: 0.9675
# Epoch 97/100
# 128/128 [==============================] - 1s 5ms/step - loss: 0.0903 - accuracy: 0.9653
# Epoch 98/100
# 128/128 [==============================] - 1s 6ms/step - loss: 0.0891 - accuracy: 0.9638
# Epoch 99/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0879 - accuracy: 0.9650
# Epoch 100/100
# 128/128 [==============================] - 0s 4ms/step - loss: 0.0869 - accuracy: 0.9667

# %%
tf_preds2 = model_4.predict(X_test_ct)
# Out:
# 32/32 [==============================] - 0s 2ms/step

# %%
tf_preds_round2 = tf.round(tf_preds2)
plot_confusion(Y_test,tf_preds_round2)

# %%
from sklearn.metrics import classification_report
print(classification_report(y_true=Y_test, y_pred=tf_preds_round2))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00       972
#            1       0.05      1.00      0.09        50
#
#     accuracy                           0.05      1022
#    macro avg       0.02      0.50      0.05      1022
# weighted avg       0.00      0.05      0.00      1022
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.9/dist-packages/sklearn/metrics/_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
from joblib import dump

#Save Model to File
dump(model_4, filename="Stroke_Model.joblib")
# Out:
# ['Stroke_Model.joblib']

# %%
#HDF5 format
model_4.save("Stroke_model_hdf5_soft.h5")
